# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
import pandas as pd
df = pd.read_excel("items.xlsx")
df
# Out:
#                      Campo   \
# 0                   Proceso
# 1               Solicitante
# 2                     Cargo
# 3                      cite
# 4                     fecha
# 5                     Monto
# 6                  Partidas
# 7              Antecedentes
# 8                Desarrollo
# 9              Conclusiones
# 10          Recomendaciones
# 11                    Final
# 12            lugar_entrega
# 13            plazo entrega
# 14                 garantia
# 15                  validez
# 16  documentacion_requerida
#
#                                                 Valor  \
# 0   GOM – Adquisición de pasadores y soportes de p...
# 1                                    Raúl Mamani Cusi
# 2                            Técnico Eléctrico Senior
# 3             GOM-DMA-RMC-0337-INF/24 (MT/2024-05109)
# 4                                  9 de julio de 2024
# 5                                              211000
# 6                                               39800
# ...
